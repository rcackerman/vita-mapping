# %%
import pandas as pd

# %% [markdown]
# ## Importing MFT data

# %%
mft_df = pd.read_excel("MFT Returns by Zip 2019.xlsx", dtype={'Zip': object})

# %%
mft_df.columns
# Out:
# Index(['Zip', 'City', 'State', 'County', 'Org ID', 'United Way',
#        '#e-filed returns', '#EITC returns', 'Average EITC Amount',
#        'Average Refund Amount', 'Average Age'],
#       dtype='object')

# %% [markdown]
# #### Dropping columns with sensistive data

# %%
mft_df.drop(axis='columns', labels=['#EITC returns', 'Average EITC Amount', 'Average Refund Amount', 'Average Age'], inplace=True)

# %% [markdown]
# #### Dropping unprocessable rows

# %%
print(mft_df[pd.isnull(mft_df['United Way'])].size); print(mft_df.size)
# Out:
# 3619
# 125545

# %% [markdown]
# Dropping any row that has a letter in the zip code or doesn't have an associated United Way. Because we will be filling unmatched zip codes with the closest zip code served by the same United Way, we can't use rows without a United Way. Luckily, the rows without a United Way appear to mostly be the rows with nonexistent or malformed zip codes.
#
# This removes 3,619 rows from the data set, out of 125,545 total rows.

# %%
mft_df = mft_df[~mft_df.Zip.str.match("[a-zA-Z]") & ~pd.isnull(mft_df['United Way'])]

# %%
mft_df[['Zip', '#e-filed returns']].to_csv("mft_returns_2019.csv", index=False)

# %% [markdown]
# ### Importing ACS data

# %%
acs = pd.read_csv("ACS 2019_income_data_zip_accessible.csv", dtype={'ZIP': object})

# %% [markdown]
# ### Merging ACS and MFT data

# %% [markdown]
# Right outer merge will get all rows from the MFT dataset and any rows from the ACS dataset that match.

# %%
merged = pd.merge(acs, mft_df, how="right", left_on="ZIP", right_on="Zip")

# %% [markdown]
# Sorting on zip because we'll be filling missing zip codes with their neighbors.

# %%
merged = merged.sort_values('Zip')

# %% [markdown]
# Forward filling missing zip codes. I.e. if we have two rows like
#
# row | zip
# ----|------
# 1  | 48103
# 2  | NA
#
# then the NA will become 48103.

# %%
merged["filled_zip"] = merged.groupby('United Way').apply(lambda group: group['ZIP'].fillna(method='ffill')).reset_index(level=0, drop="True")

# %% [markdown]
# Looking to see if there are any clusters we should be worried about. It mostly looks good - even when there are big clusters of zip codes, they appear to mainly be in the same city.

# %%
top5_filled_zips = merged[['filled_zip']].value_counts().head(5).reset_index()['filled_zip']

# %%
merged[merged.filled_zip.isin(top5_filled_zips)]
# Out:
#          ZIP    total  me_total  vita_eligible  vita_per_capita  \
# 1804   11239   6705.0     193.0         5285.0         0.788218
# 1805     NaN      NaN       NaN            NaN              NaN
# 1806     NaN      NaN       NaN            NaN              NaN
# 1807     NaN      NaN       NaN            NaN              NaN
# 1808     NaN      NaN       NaN            NaN              NaN
# 1809     NaN      NaN       NaN            NaN              NaN
# 1810     NaN      NaN       NaN            NaN              NaN
# 13609  77099  17017.0     553.0        11869.0         0.697479
# 13610    NaN      NaN       NaN            NaN              NaN
# 13611    NaN      NaN       NaN            NaN              NaN
# 13612    NaN      NaN       NaN            NaN              NaN
# 13613    NaN      NaN       NaN            NaN              NaN
# 13614    NaN      NaN       NaN            NaN              NaN
# 13615    NaN      NaN       NaN            NaN              NaN
# 15127  87144  14444.0     431.0         5628.0         0.389643
# 15128    NaN      NaN       NaN            NaN              NaN
# 15129    NaN      NaN       NaN            NaN              NaN
# 15130    NaN      NaN       NaN            NaN              NaN
# 15131    NaN      NaN       NaN            NaN              NaN
# 15132    NaN      NaN       NaN            NaN              NaN
# 15133    NaN      NaN       NaN            NaN              NaN
# 15134    NaN      NaN       NaN            NaN              NaN
# 15135    NaN      NaN       NaN            NaN              NaN
# 15136    NaN      NaN       NaN            NaN              NaN
# 15137    NaN      NaN       NaN            NaN              NaN
# 15138    NaN      NaN       NaN            NaN              NaN
# 15728  92155      0.0      12.0            0.0              NaN
# 15729    NaN      NaN       NaN            NaN              NaN
# 15730    NaN      NaN       NaN            NaN              NaN
# 15731    NaN      NaN       NaN            NaN              NaN
# 15732    NaN      NaN       NaN            NaN              NaN
# 15733    NaN      NaN       NaN            NaN              NaN
# 15734    NaN      NaN       NaN            NaN              NaN
# 15735    NaN      NaN       NaN            NaN              NaN
# 16171  93730   4454.0     216.0         1018.0         0.228559
# 16172    NaN      NaN       NaN            NaN              NaN
# 16173    NaN      NaN       NaN            NaN              NaN
# 16174    NaN      NaN       NaN            NaN              NaN
# 16175    NaN      NaN       NaN            NaN              NaN
# 16176    NaN      NaN       NaN            NaN              NaN
# 16177    NaN      NaN       NaN            NaN              NaN
# 16178    NaN      NaN       NaN            NaN              NaN
# 16179    NaN      NaN       NaN            NaN              NaN
# 16180    NaN      NaN       NaN            NaN              NaN
# 16181    NaN      NaN       NaN            NaN              NaN
#
#                    id    Zip         City State      County  Org ID  \
# 1804   8600000US11239  11239     Brooklyn    NY       Kings  34370F
# 1805              NaN  11247     Brooklyn    NY       Kings  34370F
# 1806              NaN  11249     Brooklyn    NY       Kings  34370F
# 1807              NaN  11300          NaN   NaN         NaN  34370F
# 1808              NaN  11312          NaN   NaN         NaN  34370F
# 1809              NaN  11318          NaN   NaN         NaN  34370F
# 1810              NaN  11347          NaN   NaN         NaN  34370F
# 13609  8600000US77099  77099      Houston    TX      Harris  46377F
# 13610             NaN  77235      Houston    TX      Harris  46377F
# 13611             NaN  77238      Houston    TX      Harris  46377F
# 13612             NaN  77242      Houston    TX      Harris  46377F
# 13613             NaN  77266      Houston    TX      Harris  46377F
# 13614             NaN  77268      Houston    TX      Harris  46377F
# 13615             NaN  77271      Houston    TX      Harris  46377F
# 15127  8600000US87144  87144   Rio Rancho    NM    Sandoval  33010F
# 15128             NaN  87153  Albuquerque    NM  Bernalillo  33010F
# 15129             NaN  87154  Albuquerque    NM  Bernalillo  33010F
# 15137          United Way of Central New Mexico               1.0      87144
# 15138          United Way of Central New Mexico               2.0      87144
# 15728            United Way of San Diego County               1.0      92155
# 15729            United Way of San Diego County               1.0      92155
# 15730            United Way of San Diego County               3.0      92155
# 15731            United Way of San Diego County               1.0      92155
# 15732            United Way of San Diego County               1.0      92155
# 15733            United Way of San Diego County               1.0      92155
# 15734            United Way of San Diego County               1.0      92155
# 15735            United Way of San Diego County               1.0      92155
# 16171  United Way of Fresno and Madera Counties               5.0      93730
# 16172  United Way of Fresno and Madera Counties               4.0      93730
# 16173  United Way of Fresno and Madera Counties               6.0      93730
# 16174  United Way of Fresno and Madera Counties               2.0      93730
# 16175  United Way of Fresno and Madera Counties               3.0      93730
# 16176  United Way of Fresno and Madera Counties               1.0      93730
# 16177  United Way of Fresno and Madera Counties               1.0      93730
# 16178  United Way of Fresno and Madera Counties               2.0      93730
# 16179  United Way of Fresno and Madera Counties               2.0      93730
# 16180  United Way of Fresno and Madera Counties               1.0      93730
# 16181  United Way of Fresno and Madera Counties               1.0      93730

# %% [markdown]
# Aggregate multiple rows of zip codes into one, getting a sum of the # of e-files and the not-nil row values for everything else.

# %%
# sorting by ZIP instead of Zip makes sure we have the ACS row first
agg = merged.sort_values('ZIP').groupby('filled_zip').agg({'ZIP': 'first', 
                                                     'total': 'first',
                                                     'me_total': 'first',
                                                     'vita_eligible': 'first',
                                                     'vita_per_capita': 'first',
                                                     'id': 'first',
                                                     'City': 'first',
                                                     'State': 'first',
                                                     'County': 'first',
                                                     'Org ID': 'first',
                                                     'United Way': 'first',
                                                     '#e-filed returns': 'sum',
                                                     'filled_zip': 'first'})

# %%
agg[agg.filled_zip.isin(top5_filled_zips)]
# Out:
#               ZIP    total  me_total  vita_eligible  vita_per_capita  \
# filled_zip
# 11239       11239   6705.0     193.0         5285.0         0.788218
# 77099       77099  17017.0     553.0        11869.0         0.697479
# 87144       87144  14444.0     431.0         5628.0         0.389643
# 92155       92155      0.0      12.0            0.0              NaN
# 93730       93730   4454.0     216.0         1018.0         0.228559
#
#                         id        City State     County  Org ID  \
# filled_zip
# 11239       8600000US11239    Brooklyn    NY      Kings  34370F
# 77099       8600000US77099     Houston    TX     Harris  46377F
# 87144       8600000US87144  Rio Rancho    NM   Sandoval  33010F
# 92155       8600000US92155   San Diego    CA  San Diego  05405U
# 93730       8600000US93730      Fresno    CA     Fresno  05105F
#
#                                           United Way  #e-filed returns  \
# filled_zip
# 11239                    United Way of New York City              58.0
# 77099                  United Way of Greater Houston              13.0
# 87144               United Way of Central New Mexico              64.0
# 92155                 United Way of San Diego County              10.0
# 93730       United Way of Fresno and Madera Counties              28.0
#
#            filled_zip
# filled_zip
# 11239           11239
# 77099           77099
# 87144           87144
# 92155           92155
# 93730           93730

# %%
agg.to_csv("ACS_MFT_2019_data.csv")
